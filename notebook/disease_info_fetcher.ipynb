# %% [markdown]
# <a href="https://colab.research.google.com/github/santimarro/hpo-disease-info-fetcher/blob/main/notebook/disease_info_fetcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Overview
#
# This notebook allows you to search for diseases and retrieve information about them, including associated symptoms, by providing a list of disease names. The program uses the Human Phenotype Ontology (HPO) API to search for diseases and fetch the relevant data. It employs fuzzy string matching to select the closest matching disease when multiple results are found.
#
# ## Dependencies
#
# To run the program, make sure you have the following Python libraries installed:
#
# - requests
# - fuzzywuzzy
# - python-Levenshtein
#
# You can install them using pip:
#
# ```
# pip install requests fuzzywuzzy python-Levenshtein
# ```
#
# ## How to use
#
# 1. Import the `get_disease_data` function from the program:
#
# 2. Provide a list of disease names that you want to search for:
#
# ```python
# disease_names = ["Marfan syndrome", "Ehlers-Danlos syndrome"]
# ```
#
# 3. Call the `get_disease_data` function with the list of disease names. This function returns a list of dictionaries containing the disease information and associated symptoms:
#
# ```python
# disease_data = get_disease_data(disease_names)
# ```
#
# 4. Process the returned `disease_data` as needed. Each dictionary in the list contains the disease information and its associated symptoms. For example, you can print the disease data:
#
# ```python
# print(disease_data)
# ```
#
# ## Example usage
#
# ```python
# from disease_info_fetcher import get_disease_data
#
# disease_names = ["Marfan syndrome", "Ehlers-Danlos syndrome"]
# disease_data = get_disease_data(disease_names)
# print(disease_data)
# ```
#
# This example demonstrates how to search for two diseases, "Marfan syndrome" and "Ehlers-Danlos syndrome," and print the retrieved information and associated symptoms.

# %%
pip install requests

# %%
# !pip install fuzzywuzzy python-Levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.10/dist-packages (0.18.0)
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.21.0-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.21.0
#   Downloading Levenshtein-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 14.9 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=2.3.0
#   Downloading rapidfuzz-3.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 78.8 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.21.0 python-Levenshtein-0.21.0 rapidfuzz-3.0.0

# %%
import requests
from fuzzywuzzy import process

def search_diseases(disease_name):
    url = "https://hpo.jax.org/api/hpo/search"
    params = {"q": disease_name, "category": "diseases"}
    response = requests.get(url, params=params)
    
    if response.status_code == 200:
        search_results = response.json()
        return search_results["diseases"]
    else:
        print(f"Error searching diseases for {disease_name}: {response.status_code}")
        return []

def select_closest_disease(disease_name, search_results):
    disease_names = [entry["dbName"] for entry in search_results]
    closest_name, _ = process.extractOne(disease_name, disease_names)
    closest_names = process.extract(disease_name, disease_names, limit=2)
  
    find_orpha = False
    max_score = 0
    first_name, first_score = closest_names[0]
    second_name, second_score = closest_names[1]

    if first_name == second_name:
      # we have the same disease repeated. This means two ids, orpha and omim
      find_orpha = True
    
    for entry in search_results:
        if entry["dbName"] == closest_name:
          if find_orpha:
            if entry["db"] == "ORPHA":
              return entry["diseaseId"]
          else:
            return entry["diseaseId"]

    return None

def get_disease_info(disease_id):
    url = f"https://hpo.jax.org/api/hpo/disease/{disease_id}"
    response = requests.get(url)
    
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching disease info for {disease_id}: {response.status_code}")
        return None

def get_disease_symptoms(disease_id):
    url = f"https://hpo.jax.org/api/hpo/disease/{disease_id}/phenotypes"
    response = requests.get(url)
    
    if response.status_code == 200:
        return [entry["phenotype"] for entry in response.json()]
    else:
        print(f"Error fetching symptoms for {disease_id}: {response.status_code}")
        return []

def get_disease_data(disease_names):
    disease_data = []
    
    for disease_name in disease_names:
        search_results = search_diseases(disease_name)
        closest_disease_id = select_closest_disease(disease_name, search_results)
        
        if closest_disease_id is not None:
            disease_info = get_disease_info(closest_disease_id)
            if disease_info is not None:
                # disease_info["symptoms"] = get_disease_symptoms(closest_disease_id)
                disease_data.append(disease_info)
    
    return disease_data

# Example usage
disease_names = ["Sarcoidosis", "Marfan syndrome", "Ehlers-Danlos syndrome"]
disease_data = get_disease_data(disease_names)
print(disease_data)
# Out:
# [{'disease': {'diseaseId': 'ORPHA:797', 'diseaseName': 'Sarcoidosis', 'dbId': '797', 'db': 'ORPHA'}, 'geneAssoc': [{'geneSymbol': 'HLA-DRB1', 'geneId': 3123}, {'geneSymbol': 'BTNL2', 'geneId': 56244}], 'catTermsMap': [{'catLabel': 'Blood and blood-forming tissues', 'terms': [{'ontologyId': 'HP:0001873', 'name': 'Thrombocytopenia', 'definition': 'A reduction in the number of circulating thrombocytes.', 'frequency': 'Frequent', 'onset': '', 'sources': 'ORPHA:797'}, {'ontologyId': 'HP:0001903', 'name': 'Anemia', 'definition': 'A reduction in erythrocytes volume or hemoglobin concentration.', 'frequency': 'Occasional', 'onset': '', 'sources': 'ORPHA:797'}, {'ontologyId': 'HP:0001878', 'name': 'Hemolytic anemia', 'definition': 'A type of anemia caused by premature destruction of red blood cells (hemolysis).', 'frequency': 'Very rare', 'onset': '', 'sources': 'ORPHA:797'}]}, {'catLabel': 'Connective tissue', 'terms': [{'ontologyId': 'HP:0100699', 'name': 'Scarring', 'definition': 'A scar refers to a lesion in which wound, burn, or sore has not healed completely and fibrous connective tissue has developed.', 'frequency': 'Occasional', 'onset': '', 'sources': 'ORPHA:797'}]}, {'catLabel': 'Head and neck', 'terms': [{'ontologyId': 'HP:0000433', 'name': 'Abnormal nasal mucosa morphology', 'definition': '', 'frequency': 'Occasional', 'onset': '', 'sources': 'ORPHA:797'}, {'ontologyId': 'HP:0000502', 'name': 'Abnormal conjunctiva morphology', 'definition': 'An abnormality of the conjunctiva.', 'frequency': 'Occasional', 'onset': '', 'sources': 'ORPHA:797'}, {'ontologyId': 'HP:0000620', 'name': 'Dacryocystitis', 'definition': 'Inflammation of the nasolacrimal sac.', 'frequency': 'Occasional', 'onset': '', 'sources': 'ORPHA:797'}, {'ontologyId': 'HP:0007734', 'name': 'Enlarged lacrimal glands', 'definition': 'Abnormally big lacrimal glands.', 'frequency': 'Occasional', 'onset': '', 'sources': 'ORPHA:797'}, {'ontologyId': 'HP:0011801', 'name': 'Enlargement of parotid gland', 'definition': 'Increased size of the parotid gland.', 'frequency': 'Occasional', 'onset': '', 'sources': 'ORPHA:797'}, {'ontologyId': 'HP:0011850', 'name': 'Parotitis', 'definition': 'Inflammation of the parotid gland.', 'frequency': 'Occasional', 'onset': '', 'sources': 'ORPHA:797'}]}, {'catLabel': 'Metabolism/Laboratory abnormality', 'terms': [{'ontologyId': 'HP:0001386', 'name': 'Joint swelling', 'definition': '', 'frequency': 'Frequent', 'onset': '', 'sources': 'ORPHA:797'}, {'ontologyId': 'HP:0001945', 'name': 'Fever', 'definition': 'Body temperature elevated above the normal range.', 'frequency': 'Frequent', 'onset': '', 'sources': 'ORPHA:797'}, {'ontologyId': 'HP:0003072', 'name': 'Hypercalcemia', 'definition': 'An abnormally increased calcium concentration in the blood.', 'frequency': 'Occasional', 'onset': '', 'sources': 'ORPHA:797'}, {'ontologyId': 'HP:0002045', 'name': 'Hypothermia', 'definition': 'Reduced body temperature due to failed thermoregulation.', 'frequency': 'Very rare', 'onset': '', 'sources': 'ORPHA:797'}]}, {'catLabel': 'Cardiovascular', 'terms': [{'ontologyId': 'HP:0001409', 'name': 'Portal hypertension', 'definition': 'Increased pressure in the portal vein.', 'frequency': 'Occasional', 'onset': '', 'sources': 'ORPHA:797'}, {'ontologyId': 'HP:0002716', 'name': 'Lymphadenopathy', 'definition': 'Enlargment (swelling) of a lymph node.', 'frequency': 'Occasional', 'onset': '', 'sources': 'ORPHA:797'}, {'ontologyId': 'HP:0002733', 'name': 'Abnormal lymph node morphology', 'definition': 'A structural lymph node abnormality.', 'frequency': 'Occasional', 'onset': '', 'sources': 'ORPHA:797'}, {'ontologyId': 'HP:0004756', 'name': 'Ventricular tachycardia', 'definition': 'A tachycardia originating in the ventricles characterized by rapid heart rate (over 100 beats per minute) and broad QRS complexes (over 120 ms).', 'frequency': 'Occasional', 'onset': '', 'sources': 'ORPHA:797'}, {'ontologyId': 'HP:0011675', 'name': 'Arrhythmia', 'definition': 'Any cardiac  ...

# %%
# Symptoms can be found under the catTermsMap key
print("Disease {}\n".format(disease_data[0]["disease"]["diseaseName"]))

print("Symptoms:\n")
disease_data[0]["catTermsMap"]
# Out:
# Disease Sarcoidosis
#
# Symptoms:
# [{'catLabel': 'Blood and blood-forming tissues',
#   'terms': [{'ontologyId': 'HP:0001873',
#     'name': 'Thrombocytopenia',
#     'definition': 'A reduction in the number of circulating thrombocytes.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0001903',
#     'name': 'Anemia',
#     'definition': 'A reduction in erythrocytes volume or hemoglobin concentration.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0001878',
#     'name': 'Hemolytic anemia',
#     'definition': 'A type of anemia caused by premature destruction of red blood cells (hemolysis).',
#     'frequency': 'Very rare',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Connective tissue',
#   'terms': [{'ontologyId': 'HP:0100699',
#     'name': 'Scarring',
#     'definition': 'A scar refers to a lesion in which wound, burn, or sore has not healed completely and fibrous connective tissue has developed.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Head and neck',
#   'terms': [{'ontologyId': 'HP:0000433',
#     'name': 'Abnormal nasal mucosa morphology',
#     'definition': '',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0000502',
#     'name': 'Abnormal conjunctiva morphology',
#     'definition': 'An abnormality of the conjunctiva.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0000620',
#     'name': 'Dacryocystitis',
#     'definition': 'Inflammation of the nasolacrimal sac.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0007734',
#     'name': 'Enlarged lacrimal glands',
#     'definition': 'Abnormally big lacrimal glands.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0011801',
#     'name': 'Enlargement of parotid gland',
#     'definition': 'Increased size of the parotid gland.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0011850',
#     'name': 'Parotitis',
#     'definition': 'Inflammation of the parotid gland.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Metabolism/Laboratory abnormality',
#   'terms': [{'ontologyId': 'HP:0001386',
#     'name': 'Joint swelling',
#     'definition': '',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0001945',
#     'name': 'Fever',
#     'definition': 'Body temperature elevated above the normal range.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0003072',
#     'name': 'Hypercalcemia',
#     'definition': 'An abnormally increased calcium concentration in the blood.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002045',
#     'name': 'Hypothermia',
#     'definition': 'Reduced body temperature due to failed thermoregulation.',
#     'frequency': 'Very rare',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Cardiovascular',
#   'terms': [{'ontologyId': 'HP:0001409',
#     'name': 'Portal hypertension',
#     'definition': 'Increased pressure in the portal vein.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002716',
#     'name': 'Lymphadenopathy',
#     'definition': 'Enlargment (swelling) of a lymph node.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002733',
#     'name': 'Abnormal lymph node morphology',
#     'definition': 'A structural lymph node abnormality.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0004756',
#     'name': 'Ventricular tachycardia',
#     'definition': 'A tachycardia originating in the ventricles characterized by rapid heart rate (over 100 beats per minute) and broad QRS complexes (over 120 ms).',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0011675',
#     'name': 'Arrhythmia',
#     'definition': 'Any cardiac rhythm other than the normal sinus rhythm. Such a rhythm may be either of sinus or ectopic origin and either regular or irregular. An arrhythmia may be due to a disturbance in impulse formation or conduction or both.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0012722',
#     'name': 'Heart block',
#     'definition': 'Impaired conduction of cardiac impulse occurring anywhere along the conduction pathway.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0030872',
#     'name': 'Abnormal cardiac ventricular function',
#     'definition': 'An abnormality of the cardiac ventricular function.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Digestive System',
#   'terms': [{'ontologyId': 'HP:0001410',
#     'name': 'Decreased liver function',
#     'definition': 'Reduced ability of the liver to perform its functions.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0001399',
#     'name': 'Hepatic failure',
#     'definition': '',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002240',
#     'name': 'Hepatomegaly',
#     'definition': 'Abnormally increased size of the liver.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0011024',
#     'name': 'Abnormality of the gastrointestinal tract',
#     'definition': 'An abnormality of the gastrointestinal tract.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0030146',
#     'name': 'Abnormal liver parenchyma morphology',
#     'definition': 'A structural anomaly of the liver located predominantly in the hepatocytes as opposed to stromal cells.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Endocrine',
#   'terms': [{'ontologyId': 'HP:0000873',
#     'name': 'Diabetes insipidus',
#     'definition': 'A state of excessive water intake and hypotonic (dilute) polyuria. Diabetes insipidus may be due to failure of vasopressin (AVP) release (central or neurogenic diabetes insipidus) or to a failure of the kidney to respond to AVP (nephrogenic diabetes insipidus).',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0000821',
#     'name': 'Hypothyroidism',
#     'definition': 'Deficiency of thyroid hormone.',
#     'frequency': 'Very rare',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0000834',
#     'name': 'Abnormality of the adrenal glands',
#     'definition': 'Abnormality of the adrenal glands, i.e., of the endocrine glands located at the top of the kindneys.',
#     'frequency': 'Very rare',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0000836',
#     'name': 'Hyperthyroidism',
#     'definition': "An abnormality of thyroid physiology characterized by excessive secretion of the thyroid hormones thyroxine (i.e., T4) and/or 3,3',5-triiodo-L-thyronine zwitterion (i.e., triiodothyronine or T3).",
#     'frequency': 'Very rare',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Eye',
#   'terms': [{'ontologyId': 'HP:0000554',
#     'name': 'Uveitis',
#     'definition': 'Inflammation of one or all portions of the uveal tract.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0000501',
#     'name': 'Glaucoma',
#     'definition': 'Glaucoma refers loss of retinal ganglion cells in a characteristic pattern of optic neuropathy usually associated with increased intraocular pressure.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0000518',
#     'name': 'Cataract',
#     'definition': 'A cataract is an opacity or clouding that develops in the crystalline lens of the eye or in its capsule.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0000618',
#     'name': 'Blindness',
#     'definition': 'Blindness is the condition of lacking visual perception defined as visual perception below 3/60 and/or a visual field of no greater than 10 degrees in radius around central fixation.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Genitourinary system',
#   'terms': [{'ontologyId': 'HP:0000083',
#     'name': 'Renal insufficiency',
#     'definition': 'A reduction in the level of performance of the kidneys in areas of function comprising the concentration of urine, removal of wastes, the maintenance of electrolyte balance, homeostasis of blood pressure, and calcium metabolism.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0000121',
#     'name': 'Nephrocalcinosis',
#     'definition': 'Nephrocalcinosis is the deposition of calcium salts in renal parenchyma.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0000787',
#     'name': 'Nephrolithiasis',
#     'definition': 'The presence of calculi (stones) in the kidneys.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0001970',
#     'name': 'Tubulointerstitial nephritis',
#     'definition': 'A form of inflammation of the kidney affecting the interstitium of the kidneys surrounding the tubules.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002150',
#     'name': 'Hypercalciuria',
#     'definition': '',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0012243',
#     'name': 'Abnormal reproductive system morphology',
#     'definition': 'A structural or developmental anomaly of any of the tissues involved in the genital system.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Immunology',
#   'terms': [{'ontologyId': 'HP:0001882',
#     'name': 'Leukopenia',
#     'definition': 'An abnormal decreased number of leukocytes in the blood.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0012219',
#     'name': 'Erythema nodosum',
#     'definition': 'An erythematous eruption commonly associated with drug reactions or infection and characterized by inflammatory nodules that are usually tender, multiple, and bilateral.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0100828',
#     'name': 'Increased T cell count',
#     'definition': 'An abnormal increase in the total number of T cells detected in the blood.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0001097',
#     'name': 'Keratoconjunctivitis sicca',
#     'definition': 'Dryness of the eye related to deficiency of the tear film components (aqueous, mucin, or lipid), lid surface abnormalities, or epithelial abnormalities. Keratoconjunctivitis sicca often results in a scratchy or sandy sensation (foreign body sensation) in the eyes, and may also be associated with itching, inability to produce tears, photosensitivity, redness, pain, and difficulty in moving the eyelids.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0040186',
#     'name': 'Maculopapular exanthema',
#     'definition': 'A skin rash that is characterized by diffuse cutaneous erythema with areas of skin elevation. It may evolve to vesicles or papules as part of a more severe clinical entity. Different degrees of angioedema with involvement of subcutaneous tissue may also appear.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0001880',
#     'name': 'Eosinophilia',
#     'definition': 'Increased count of eosinophils in the blood.',
#     'frequency': 'Very rare',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Skin, Hair, and Nails',
#   'terms': [{'ontologyId': 'HP:0011121',
#     'name': 'Abnormality of skin morphology',
#     'definition': 'Any morphological abnormality of the skin.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0200036',
#     'name': 'Skin nodule',
#     'definition': 'Morphologically similar to a papule, but greater than either 10mm in both width and depth, and most frequently centered in the dermis or subcutaneous fat.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0000953',
#     'name': 'Hyperpigmentation of the skin',
#     'definition': 'A darkening of the skin related to an increase in melanin production and deposition.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0001010',
#     'name': 'Hypopigmentation of the skin',
#     'definition': 'A reduction of skin color related to a decrease in melanin production and deposition.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0001482',
#     'name': 'Subcutaneous nodule',
#     'definition': 'Slightly elevated lesions on or in the skin with a diameter of over 5 mm.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0001596',
#     'name': 'Alopecia',
#     'definition': 'A noncongenital process of hair loss, which may progress to partial or complete baldness.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0200035',
#     'name': 'Skin plaque',
#     'definition': 'A plaque is a solid, raised, plateau-like (flat-topped) lesion greater than 1 cm in diameter.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Musculature',
#   'terms': [{'ontologyId': 'HP:0003701',
#     'name': 'Proximal muscle weakness',
#     'definition': 'A lack of strength of the proximal muscles.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Nervous System',
#   'terms': [{'ontologyId': 'HP:0002921',
#     'name': 'Abnormal cerebrospinal fluid morphology',
#     'definition': 'An abnormality of the cerebrospinal fluid (CSF).',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002922',
#     'name': 'Increased CSF protein concentration',
#     'definition': 'Increased concentration of protein in the cerebrospinal fluid.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0009830',
#     'name': 'Peripheral neuropathy',
#     'definition': 'Peripheral neuropathy is a general term for any disorder of the peripheral nervous system. The main clinical features used to classify peripheral neuropathy are distribution, type (mainly demyelinating versus mainly axonal), duration, and course.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0010628',
#     'name': 'Facial palsy',
#     'definition': 'Facial nerve palsy is a dysfunction of cranial nerve VII (the facial nerve) that results in inability to control facial muscles on the affected side with weakness of the muscles of facial expression and eye closure. This can either be present in unilateral or bilateral form.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Respiratory System',
#   'terms': [{'ontologyId': 'HP:0002088',
#     'name': 'Abnormal lung morphology',
#     'definition': 'Any structural anomaly of the lung.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002094',
#     'name': 'Dyspnea',
#     'definition': 'Difficult or labored breathing. Dyspnea is a subjective feeling only the patient can rate, e.g., on a Borg scale.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002103',
#     'name': 'Abnormal pleura morphology',
#     'definition': 'An abnormality of the pulmonary pleura, the thin, transparent membrane which covers the lungs and lines the inside of the chest walls.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002202',
#     'name': 'Pleural effusion',
#     'definition': 'The presence of an excessive amount of fluid in the pleural cavity.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0012735',
#     'name': 'Cough',
#     'definition': 'A sudden, audible expulsion of air from the lungs through a partially closed glottis, preceded by inhalation.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002097',
#     'name': 'Emphysema',
#     'definition': '',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002107',
#     'name': 'Pneumothorax',
#     'definition': 'Accumulation of air in the pleural cavity leading to a partially or completely collapsed lung.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002110',
#     'name': 'Bronchiectasis',
#     'definition': 'Persistent abnormal dilatation of the bronchi owing to localized and irreversible destruction and widening of the large airways.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002206',
#     'name': 'Pulmonary fibrosis',
#     'definition': 'Replacement of normal lung tissues by fibroblasts and collagen.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002781',
#     'name': 'Upper airway obstruction',
#     'definition': 'Increased resistance to the passage of air in the upper airway.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0010310',
#     'name': 'Chylothorax',
#     'definition': 'Accumulation of excessive amounts of lymphatic fluid (chyle) in the pleural cavity.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0002105',
#     'name': 'Hemoptysis',
#     'definition': 'Coughing up (expectoration) of blood or blood-streaked sputum from the larynx, trachea, bronchi, or lungs.',
#     'frequency': 'Very rare',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Skeletal system',
#   'terms': [{'ontologyId': 'HP:0012062',
#     'name': 'Bone cyst',
#     'definition': 'A fluid filled cavity that develops with a bone.',
#     'frequency': 'Occasional',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Growth',
#   'terms': [{'ontologyId': 'HP:0001824',
#     'name': 'Weight loss',
#     'definition': 'Reduction of total body weight.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'}]},
#  {'catLabel': 'Constitutional Symptom',
#   'terms': [{'ontologyId': 'HP:0012378',
#     'name': 'Fatigue',
#     'definition': 'A subjective feeling of tiredness characterized by a lack of energy and motivation.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'},
#    {'ontologyId': 'HP:0100749',
#     'name': 'Chest pain',
#     'definition': 'An unpleasant sensation characterized by physical discomfort (such as pricking, throbbing, or aching) localized to the chest.',
#     'frequency': 'Frequent',
#     'onset': '',
#     'sources': 'ORPHA:797'}]}]
